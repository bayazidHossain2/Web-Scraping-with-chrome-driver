# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup
import time
import pandas as pd
import datetime
import os

# Get the current date and time
current_datetime = datetime.datetime.now().strftime("%Y-%m-%d %H-%M-%S")
if not os.path.exists(current_datetime):
    os.makedirs(current_datetime)

# %%
print(current_datetime)
# Out:
# 2024-08-11 19-30-10

# %% [markdown]
# ## Initialize WebDriver

# %%
# Initialize WebDriver with the path to ChromeDriver using Service
driver_path = r"chromedriver-win64\chromedriver-win64\chromedriver.exe"
service = Service(driver_path)
driver = webdriver.Chrome(service=service)

# %% [markdown]
# ## Get Video Title from chanels

# %%
def get_video_title_from_channel_url(channel_url):    
    # Open YouTube channel
    # channel_url = "https://www.youtube.com/@Apple"
    driver.get(channel_url)
    
    # Wait for the page to load
    time.sleep(5)
    
    # Scroll down to load more content
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(5)
    
    # Example: Scraping the number of subscribers
    try:
        subscribers = driver.find_element(By.XPATH, '//span[contains(@class, "yt-content-metadata-view-model-wiz__metadata-text") and contains(text(), "subscribers")]').text
        print(f"Subscribers: {subscribers}")
    except Exception as e:
        print(f"Error finding subscribers: {e}")
    
    # Example: Scraping recent video statistics
    videos = driver.find_elements(By.XPATH, '//*[@id="video-title"]')
    
    print(len(videos))
    return videos

# get_video_title_from_channel_url('https://www.youtube.com/@amazon')

# %% [markdown]
# ## Load the video page

# %%
def get_html_from_video_link(video_url):
      
    # Open the YouTube video page
    driver.get(video_url)
    
    # Wait for the page to load
    time.sleep(5)
    # Pause the video using JavaScript
    pause_script = """
        var video = document.querySelector('video');
        if (video) {
            video.pause();
        }
    """
    driver.execute_script(pause_script)
    
    time.sleep(5)
    
    # Get the page source
    html = driver.page_source
    # print(html)
    return html

# %% [markdown]
# ## Get Number

# %%
def get_number(str):
    # Dictionary to map suffixes to their respective multipliers
    multipliers = {'k': 1_000, 'K': 1_000, 'm': 1_000_000, 'M': 1_000_000, 'b': 1_000_000_000, 'B': 1_000_000_000}

    if not str.strip():
        return 0
    elif str[-1] in multipliers:
        # Extract the number and the suffix
        num = float(str[:-1].replace(',', '.'))
        multiplier = multipliers[str[-1]]
        return int(num * multiplier)
    else:
        # If there's no suffix, just return the integer value
        return int(str.replace(',', ''))

# print(get_number('  '))

# %% [markdown]
# ## Find the views Count

# %%
def get_views_count(_soup):
    ### Find the views count element
    try:
        info_element = _soup.find('yt-formatted-string', {'id': 'info'})
        if info_element:
            views_element = info_element.find('span', {'class': 'bold style-scope yt-formatted-string'})
            if views_element:
                views_text = views_element.get_text(strip=True)
                # print(f"Views: {views_text}")
            else:
                print("Could not find views element.")
                return 0
        else:
            print("Could not find info element.")
            return 0
    except Exception as e:
        print(f"Error finding views: {e}")
        return 0

    return get_number(views_text.split(' ')[0])

# %% [markdown]
# ## Find the likes count

# %%
def get_like_count(_soup):
    ### Finding the likes on a video
    
    factoid_element = _soup.find('factoid-renderer', {'class': 'YtwFactoidRendererHost'})
    try:
        # Extract the number of likes
        if factoid_element:
            like_count_element = factoid_element.find('span', {'class': 'yt-core-attributed-string yt-core-attributed-string--white-space-pre-wrap'})
            if like_count_element:
                like_count = like_count_element.get_text(strip=True)
                # print(f"Likes: {like_count}")
            else:
                print("Could not find like count element.")
                return 0
        else:
            print("Could not find factoid element.")
            return 0
    except Exception as e:
        print(f"Error finding views: {e}")
        return 0

    return get_number(like_count)

# %% [markdown]
# ## Find the comment count

# %%
def get_comment_count(_soup):
    ### find comments
    # Find the element containing the comment count
    comment_count_element = _soup.findAll('yt-formatted-string', {'class': 'style-scope ytd-engagement-panel-title-header-renderer'}, id='contextual-info')
    # print(f'Comment count e : {comment_count_element}')
    try:
        # Extract the text from the element containing the number of comments
        if comment_count_element[1]:
            comment_count = comment_count_element[1].text.strip()
            # print(f"Number of comments: {comment_count}")
            # print(comment_count_element[1].text)
        else:
            print("Could not find the comment count element.")
            return 0
    except Exception as e:
        print(f"Error finding views: {e}")
        return 0
    

    return get_number(comment_count)

# %% [markdown]
# ## Load Channel Data

# %%
# channel_url = "https://www.youtube.com/@IBM"
# channel_name = "IBM"
def load_channel_data(channel_name, channel_url):
    videos_title = get_video_title_from_channel_url(channel_url)
    # get_video_title_from_channel_url('https://www.youtube.com/@amazon')
    
    video_title_list = list()
    video_url_list = list()
    for video in videos_title[:5]:
        video_title = video.get_attribute('title')
        video_url = video.get_attribute('href')
        video_title_list.append(video_title)
        video_url_list.append(video_url)
    
    # print(video_title_list)
    # print(video_url_list)
    
    info = list()
    for ind in range(len(video_url_list)):
        # video_title = video.get_attribute('title')
        # video_url = video.get_attribute('href')
        # print(f'title : {video_title}')
        html = get_html_from_video_link(video_url_list[ind])
        time.sleep(3)
        # Parse with BeautifulSoup
        soup = BeautifulSoup(html, 'html.parser')
        views = get_views_count(soup)
        likes = get_like_count(soup)
        comments = get_comment_count(soup)
        info.append([video_title_list[ind], video_url_list[ind], views, likes, comments])
    
        print(f'ind : {ind} {video_title_list[ind]} views : {views} likes : {likes}, comments : {comments}')
        # driver.back()
        # time.sleep(1)

    # Convert the list of lists into a DataFrame
    df = pd.DataFrame(info, columns=['Video Title', 'Video URL', 'views', 'likes', 'comments'])
    
    # Specify the file name
    filename = f"{current_datetime}/{channel_name}_data.csv"
    
    # Save the DataFrame to a CSV file
    df.to_csv(filename, index=False)
    
    print(f"Data saved to {filename}")

# load_channel_data('densy', 'https://www.youtube.com/@disneychannel')

# %%
# Load the Excel file
file_path = 'data/data.csv'

try:
    # Attempt to read the file
    channels = pd.read_csv(file_path, encoding='ISO-8859-1')  # Adjust encoding if necessary

    # Assuming the columns are named 'Brand' and 'YouTube Link'
    if 'BRANDS' in channels.columns and 'YouTube' in channels.columns:
        for index, row in channels.iterrows():
            brand = row['BRANDS']
            youtube_link = row['YouTube']
            print(f"{index} Brand: {brand}, YouTube Link: {youtube_link} Going to Load: ")
            load_channel_data(brand, youtube_link)
    else:
        print("The required columns are not found in the CSV file.")
except Exception as e:
    print(f"An error occurred: {e}")
driver.quit()
# Out:
# 0 Brand: Apple, YouTube Link: https://www.youtube.com/@Apple Going to Load:
# Subscribers: 19.2M subscribers
# 55
# ind : 0 Privacy on iPhone | Flock | Apple views : 17468530 likes : 30000, comments : 0
# ind : 1 Personal Voice on iPhone | The Lost Voice | Apple views : 18000000 likes : 16000, comments : 0
# ind : 2 The Greatest | Apple views : 18000000 likes : 35000, comments : 0
# ind : 3 Celebrating Steve | October 5 | Apple views : 6100000 likes : 274000, comments : 0
# ind : 4 Every product carbon neutral by 2030 | Apple views : 3100000 likes : 129000, comments : 0
# Data saved to 2024-08-11 19-30-10/Apple_data.csv
# 1 Brand: Google, YouTube Link: https://www.youtube.com/@Google Going to Load:
# Subscribers: 12.2M subscribers
# 41
# Could not find factoid element.
# ind : 0 Google Keynote (Google I/O ‘24) views : 2000000 likes : 0, comments : 0
# ind : 1 Google I/O 2024: Opening Film views : 85000 likes : 818, comments : 0
# ind : 2 How developers are using Gemini 1.5 Pro’s 1 million token context window views : 83000 likes : 761, comments : 0
# ind : 3 Project Astra: Our vision for the future of AI assistants views : 729000 likes : 13000, comments : 0
# ind : 4 Filmmaking with Donald Glover and his creative studio, Gilga | Veo views : 115000 likes : 2000, comments : 0
# Data saved to 2024-08-11 19-30-10/Google_data.csv
# 2 Brand: Microsoft, YouTube Link: https://www.youtube.com/@Microsoft Going to Load:
# Subscribers: 1.64M subscribers
# 54
# ind : 0 Copilot for Microsoft 365 | Reimagine what’s possible views : 9200 likes : 151, comments : 19
# ind : 1 Copilot for Microsoft 365 | Save time and focus on what matters most views : 2600 likes : 47, comments : 12
# ind : 2 Copilot for Microsoft 365 | Your AI assistant for work views : 2400000 likes : 253, comments : 10
# ind : 3 Copilot for Microsoft 365 | Enhance your productivity views : 3100000 likes : 161, comments : 23
# ind : 4 Full Keynote: Introducing Copilot+ PCs views : 400000 likes : 8100, comments : 905
# Data saved to 2024-08-11 19-30-10/Microsoft_data.csv
# 3 Brand: Amazon, YouTube Link: https://www.youtube.com/@amazon Going to Load:
# Subscribers: 605K subscribers
# 18
# ind : 0 The Best views : 2400 likes : 65, comments : 0
# ind : 1 How to Return to Home (Clock View) When Playing Audio on Echo Spot views : 493 likes : 8, comments : 0
# ind : 2 Meet the German facilities team bringing Amazon's corporate building accessibility vision to life views : 507 likes : 26, comments : 0
# ind : 3 Meet Amazon Germany's People with Disability (PwD) Affinity Group views : 287 likes : 26, comments : 0
# ind : 4 Alexa on Tablet views : 1400 likes : 24, comments : 0
# Data saved to 2024-08-11 19-30-10/Amazon_data.csv
# 4 Brand: Facebook, YouTube Link: https://www.youtube.com/@facebookapp Going to Load:
# Subscribers: 1.7M subscribers
# 23
# ind : 0 Becky G Takes on Anything with Facebook Groups views : 54000 likes : 286, comments : 96
# ind : 1 Becky G Takes on Anything with Facebook Groups views : 32000 likes : 150, comments : 55
# ind : 2 Facebook Groups: Not Wasting My Twenties views : 71000 likes : 277, comments : 256
# ind : 3 Facebook Groups: Outdoorsy Gals views : 371000 likes : 373, comments : 31
# ind : 4 Facebook Groups: screw it, let's talk astrology views : 28000 likes : 151, comments : 121
# Data saved to 2024-08-11 19-30-10/Facebook_data.csv
# 5 Brand: Coca-Cola, YouTube Link: https://www.youtube.com/@Coca-Cola Going to Load:
# Subscribers: 4.46M subscribers
# 14
# ind : 0 Gwen Stefani x Anderson .Paak – Hello World (Song of The Olympics™) Official Video views : 3700000 likes : 22000, comments : 1800
# ind : 1 Coca-Cola | It's Magic When the World Comes Together | Paris 2024 | Global  | 1m45 views : 24000 likes : 319, comments : 19
# ind : 2 Coca-Cola FanFeat – Junte seus ídolos no hit do ano views : 59000000 likes : 32000, comments : 5900
# ind : 3 Janhvi Kapoor is ready to feel the #RealMagic with Coca-Cola! views : 45000000 likes : 8500, comments : 276
# ind : 4 A year to share views : 43000000 likes : 3300, comments : 0
# Data saved to 2024-08-11 19-30-10/Coca-Cola_data.csv
# 6 Brand: Disney, YouTube Link: https://www.youtube.com/@disneychannel Going to Load:
# Subscribers: 9.28M subscribers
# 60
# ind : 0 Primos Chibi Tiny Tales | NEW CHIBI SHORT | The Summer of Silenciosa | @disneychannel views : 11000 likes : 348, comments : 0
# Could not find views element.
# Could not find factoid element.
# Error finding views: list index out of range
# ind : 1 🔴 LIVE! | Wizards of Waverly Place Season 1 Full Episodes | 21 THROWBACK Episodes | @disneychannel views : 0 likes : 0, comments : 0
# ind : 2 Wizards Beyond Waverly Place First-Look 👀🪄 | NEW SERIES! | @disneychannel views : 313000 likes : 14000, comments : 0
# ind : 3 Moon Girl’s Lab Shorts #8 | Save the Moon 🌕 | Marvel’s Moon Girl and Devil Dinosaur |@disneychannel views : 741400 likes : 428, comments : 0
# ind : 4 Descendants 3 As Told By Chibi  #DisneyDescendants #ChibiTinyTales #DisneyChannel views : 35000 likes : 1700, comments : 0
# Data saved to 2024-08-11 19-30-10/Disney_data.csv
# 7 Brand: Samsung, YouTube Link: https://www.youtube.com/@Samsung Going to Load:
# Subscribers: 6.94M subscribers
# 90
# ind : 0 The Next Big Thing Is You | Samsung views : 29000000 likes : 2200, comments : 216
# ind : 1 Introducing Galaxy Z Fold6 and Z Flip6 | Samsung views : 30000000 likes : 15000, comments : 0
# ind : 2 Galaxy Z Fold6: Circle to Search | Samsung views : 30000000 likes : 2100, comments : 213
# ind : 3 Galaxy Z Flip6: FlexCam | Samsung views : 30000000 likes : 1100, comments : 62
# ind : 4 Galaxy Z Fold6: Performance | Samsung views : 20000000 likes : 1200, comments : 119
# Data saved to 2024-08-11 19-30-10/Samsung_data.csv
# 8 Brand: Louis Vuitton, YouTube Link: https://www.youtube.com/@louisvuitton Going to Load:
# Subscribers: 5.39M subscribers
# 54
# ind : 0 Nicolas Ghesquière: Shaping Fashion | Episode 2: Jennifer Connelly | LOUIS VUITTON views : 362000 likes : 355, comments : 20
# ind : 1 Women’s Fall-Winter 2024 Campaign I LOUIS VUITTON views : 133000 likes : 4900, comments : 11
# ind : 2 Olympic Games Paris 2024 Opening Ceremony | LOUIS VUITTON views : 112000 likes : 1400, comments : 80
# ind : 3 A legendary history | LOUIS VUITTON views : 10000 likes : 372, comments : 15
# ind : 4 Louis Vuitton [Extended]— Ep15 — Antoine Dupont on the World of Rugby, His Family Roots, and Fashion views : 6300 likes : 144, comments : 4
# Data saved to 2024-08-11 19-30-10/Louis Vuitton_data.csv
# 9 Brand: McDonald's, YouTube Link: https://www.youtube.com/@McDonalds Going to Load:
# Subscribers: 706K subscribers
# 42
# Could not find factoid element.
# ind : 0 The Race to WcDonald’s | WcDonald’s Short Ep. 1 views : 218000 likes : 0, comments : 537
# Could not find factoid element.
# ind : 1 From The Makers of... views : 154000 likes : 0, comments : 375
# ind : 2 Official WcDonald's AMV w/ Studio Pierrot & official track "WANT U LUV IT" by Reol views : 203000 likes : 12000, comments : 402
# ind : 3 The Wisdom of The Sauce | WcDonald’s Short Ep. 4 (English Sub) views : 41000 likes : 1200, comments : 80
# Could not find factoid element.
# ind : 4 The Wisdom of the Sauce | WcDonald’s Short Ep. 4 views : 97000 likes : 0, comments : 235
# Data saved to 2024-08-11 19-30-10/McDonald's_data.csv
# 10 Brand: Toyota, YouTube Link: https://www.youtube.com/user/ToyotaUSA Going to Load:
# Subscribers: 796K subscribers
# 58
# ind : 0 National Sales Event | Swipe | Toyota views : 3800 likes : 39, comments : 8
# ind : 1 2024 Toyota Tundra vs 2024 Ford F-150 | Toyota views : 8200 likes : 77, comments : 0
# ind : 2 2024 RAV4 Prime PHEV vs 2024 Mitsubishi Outlander PHEV | Toyota views : 5700 likes : 45, comments : 0
# ind : 3 2024 Toyota RAV4 Prime PHEV vs 2024 Kia Sportage PHEV | Toyota views : 6800 likes : 115, comments : 0
# ind : 4 2024 - 2025 Toyota Corolla Hatchback Overview | Toyota views : 37000 likes : 382, comments : 0
# Data saved to 2024-08-11 19-30-10/Toyota_data.csv
# 11 Brand: Intel, YouTube Link: https://www.youtube.com/user/channelintel Going to Load:
# Subscribers: 556K subscribers
# 56
# ind : 0 The Ethical Development of AI Everywhere | Technically Speaking (S1 E1) | Intel views : 651 likes : 31, comments : 0
# ind : 1 AI and Sustainable Farming | Technically Speaking (S1 E2) | Intel views : 491 likes : 28, comments : 0
# ind : 2 Promoting Inclusivity with AI | Technically Speaking (S1 E3) | Intel views : 360 likes : 18, comments : 0
# ind : 3 Machine Learning meets Human Well-being | Technically Speaking (S1 E4) | Intel views : 454 likes : 30, comments : 0
# ind : 4 Supporting the Future of Transportation with AI | Technically Speaking (S1 E5) | Intel views : 552 likes : 29, comments : 0
# Data saved to 2024-08-11 19-30-10/Intel_data.csv
# 12 Brand: NIKE, YouTube Link: https://www.youtube.com/user/nike Going to Load:
# Subscribers: 2.02M subscribers
# 43
# ind : 0 WINNING ISN’T FOR EVERYONE | REGRETS | LEBRON views : 7900 likes : 464, comments : 31
# ind : 1 WINNING ISN’T FOR EVERYONE | KIMIYA ALIZADEH views : 13000 likes : 395, comments : 27
# ind : 2 WINNING ISN’T FOR EVERYONE | KEVIN DURANT | NIKE views : 25000 likes : 912, comments : 50
# ind : 3 WINNING ISN’T FOR EVERYONE | CELEBRATE | SHA’CARRI RICHARDSON views : 174000 likes : 751, comments : 65
# ind : 4 WINNING ISN’T FOR EVERYONE | WINNER | CINDY NGAMBA views : 78000 likes : 356, comments : 15
# Data saved to 2024-08-11 19-30-10/NIKE_data.csv
# 13 Brand: AT&T, YouTube Link: https://www.youtube.com/user/att Going to Load:
# Error finding subscribers: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//span[contains(@class, "yt-content-metadata-view-model-wiz__metadata-text") and contains(text(), "subscribers")]"}
#   (Session info: chrome=127.0.6533.89)
# Stacktrace:
# 	GetHandleVerifier [0x00007FF688A99632+30946]
# 	(No symbol) [0x00007FF688A4E3C9]
# 	(No symbol) [0x00007FF688946FDA]
# 	(No symbol) [0x00007FF68899822C]
# 	(No symbol) [0x00007FF68899850C]
# 	(No symbol) [0x00007FF6889DDCB7]
# 	(No symbol) [0x00007FF6889BCAAF]
# 	(No symbol) [0x00007FF6889DB041]
# 	(No symbol) [0x00007FF6889BC813]
# 	(No symbol) [0x00007FF68898A6E5]
# 	(No symbol) [0x00007FF68898B021]
# 	GetHandleVerifier [0x00007FF688BCF83D+1301229]
# 	GetHandleVerifier [0x00007FF688BDBDB7+1351783]
# 	GetHandleVerifier [0x00007FF688BD2A03+1313971]
# 	GetHandleVerifier [0x00007FF688ACDD06+245686]
# 	(No symbol) [0x00007FF688A5758F]
# 	(No symbol) [0x00007FF688A53804]
# 	(No symbol) [0x00007FF688A53992]
# 	(No symbol) [0x00007FF688A4A3EF]
# 	BaseThreadInitThunk [0x00007FFA045C257D+29]
# 	RtlUserThreadStart [0x00007FFA05F4AF28+40]
#
# 0
# Data saved to 2024-08-11 19-30-10/AT&T_data.csv
# 14 Brand: Cisco, YouTube Link: https://www.youtube.com/user/cisco Going to Load:
# Subscribers: 349K subscribers
# 89
# ind : 0 Cisco Newsroom views : 487 likes : 19, comments : 0
# ind : 1 Cisco CX: Customer Experience views : 2500 likes : 15, comments : 0
# ind : 2 Corporate Social Responsibility views : 754 likes : 14, comments : 1
# ind : 3 Cisco Live US views : 7000 likes : 53, comments : 1
# ind : 4 Partners views : 410 likes : 5, comments : 0
# Data saved to 2024-08-11 19-30-10/Cisco_data.csv
# 15 Brand: Oracle, YouTube Link: https://www.youtube.com/user/Oracle Going to Load:
# Subscribers: 135K subscribers
# 67
# ind : 0 Build Your Personalized Schedule for Oracle CloudWorld 2024 views : 467 likes : 15, comments : 1
# ind : 1 Countdown to CloudWorld 2024 views : 2100 likes : 29, comments : 0
# ind : 2 The Global Hotel Alliance Centralizes Operations with Oracle OPERA Cloud views : 295 likes : 10, comments : 1
# ind : 3 What's New in Oracle Tech Platform: July 2024 views : 1600 likes : 54, comments : 0
# Could not find factoid element.
# ind : 4 Innovate with the Combined Power of Oracle and Microsoft views : 1100 likes : 0, comments : 0
# Data saved to 2024-08-11 19-30-10/Oracle_data.csv
# 16 Brand: Verizon, YouTube Link: https://www.youtube.com/user/verizon Going to Load:
# Subscribers: 462K subscribers
# 7
# ind : 0 Test 719 - Meet Us At The Top  | Test Force Colorado | Verizon views : 3000 likes : 32, comments : 0
# ind : 1 Test 303 - Higher Calling  | Test Force Colorado | Verizon views : 1900 likes : 36, comments : 0
# ind : 2 Test 305 - Cruising Thru Congestion | Test Force Miami | Verizon views : 2500 likes : 37, comments : 0
# ind : 3 Test 239 - The Everglades Upload | Test Force Miami | Verizon views : 3000 likes : 53, comments : 0
# ind : 4 Test 815 - Can You Ear Me Now? | Test Force Chicago | Verizon views : 1800 likes : 22, comments : 0
# Data saved to 2024-08-11 19-30-10/Verizon_data.csv
# 17 Brand: Visa, YouTube Link: https://www.youtube.com/user/visacorporate Going to Load:
# Error finding subscribers: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//span[contains(@class, "yt-content-metadata-view-model-wiz__metadata-text") and contains(text(), "subscribers")]"}
#   (Session info: chrome=127.0.6533.89)
# Stacktrace:
# 	GetHandleVerifier [0x00007FF688A99632+30946]
# 	(No symbol) [0x00007FF688A4E3C9]
# 	(No symbol) [0x00007FF688946FDA]
# 	(No symbol) [0x00007FF68899822C]
# 	(No symbol) [0x00007FF68899850C]
# 	(No symbol) [0x00007FF6889DDCB7]
# 	(No symbol) [0x00007FF6889BCAAF]
# 	(No symbol) [0x00007FF6889DB041]
# 	(No symbol) [0x00007FF6889BC813]
# 	(No symbol) [0x00007FF68898A6E5]
# 	(No symbol) [0x00007FF68898B021]
# 	GetHandleVerifier [0x00007FF688BCF83D+1301229]
# 	GetHandleVerifier [0x00007FF688BDBDB7+1351783]
# 	GetHandleVerifier [0x00007FF688BD2A03+1313971]
# 	GetHandleVerifier [0x00007FF688ACDD06+245686]
# 	(No symbol) [0x00007FF688A5758F]
# 	(No symbol) [0x00007FF688A53804]
# 	(No symbol) [0x00007FF688A53992]
# 	(No symbol) [0x00007FF688A4A3EF]
# 	BaseThreadInitThunk [0x00007FFA045C257D+29]
# 	RtlUserThreadStart [0x00007FFA05F4AF28+40]
#
# 0
# Data saved to 2024-08-11 19-30-10/Visa_data.csv
# 18 Brand: Walmart, YouTube Link: https://www.youtube.com/user/Walmart Going to Load:
# Subscribers: 730K subscribers
# 12
# ind : 0 The League of Black And Unlimited Dads- Answering the Call views : 42000 likes : 542, comments : 142
# ind : 1 We Celebrate Being Black & a Disruptor with Jordan E. Cooper | Black & Unlimited​ views : 32000 likes : 275, comments : 0
# ind : 2 Just Breathe I A Film by Rodney Rikai I Black & Unlimited views : 41000 likes : 458, comments : 43
# ind : 3 Legacy of the Sea I A Film by Dior Rodriguez I Black & Unlimited views : 42000 likes : 854, comments : 151
# ind : 4 Dear Dad I A Film by Jared Malik Royal I Black & Unlimited views : 27000 likes : 434, comments : 71
# Data saved to 2024-08-11 19-30-10/Walmart_data.csv
# 19 Brand: GE, YouTube Link: https://www.youtube.com/user/GeneralElectric Going to Load:
# Error finding subscribers: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//span[contains(@class, "yt-content-metadata-view-model-wiz__metadata-text") and contains(text(), "subscribers")]"}
#   (Session info: chrome=127.0.6533.89)
# Stacktrace:
# 	GetHandleVerifier [0x00007FF688A99632+30946]
# 	(No symbol) [0x00007FF688A4E3C9]
# 	(No symbol) [0x00007FF688946FDA]
# 	(No symbol) [0x00007FF68899822C]
# 	(No symbol) [0x00007FF68899850C]
# 	(No symbol) [0x00007FF6889DDCB7]
# 	(No symbol) [0x00007FF6889BCAAF]
# 	(No symbol) [0x00007FF6889DB041]
# 	(No symbol) [0x00007FF6889BC813]
# 	(No symbol) [0x00007FF68898A6E5]
# 	(No symbol) [0x00007FF68898B021]
# 	GetHandleVerifier [0x00007FF688BCF83D+1301229]
# 	GetHandleVerifier [0x00007FF688BDBDB7+1351783]
# 	GetHandleVerifier [0x00007FF688BD2A03+1313971]
# 	GetHandleVerifier [0x00007FF688ACDD06+245686]
# 	(No symbol) [0x00007FF688A5758F]
# 	(No symbol) [0x00007FF688A53804]
# 	(No symbol) [0x00007FF688A53992]
# 	(No symbol) [0x00007FF688A4A3EF]
# 	BaseThreadInitThunk [0x00007FFA045C257D+29]
# 	RtlUserThreadStart [0x00007FFA05F4AF28+40]
#
# 0
# Data saved to 2024-08-11 19-30-10/GE_data.csv
# 20 Brand: Budweiser, YouTube Link: https://www.youtube.com/user/Budweiser Going to Load:
# Subscribers: 217K subscribers
# 19
# ind : 0 Budweiser | 2024 Folds of Honor Limited-Edition Can views : 2100 likes : 62, comments : 9
# ind : 1 Budweiser | This Bud's For You views : 4400 likes : 68, comments : 18
# ind : 2 Budweiser | Folds of Honor Founder's Story views : 13000 likes : 152, comments : 228
# ind : 3 Budweiser | Griffey Father’s Day views : 45000 likes : 190, comments : 1800
# ind : 4 Budweiser | Thank You St. Louis – Yadi & Waino views : 3800 likes : 54, comments : 25
# Data saved to 2024-08-11 19-30-10/Budweiser_data.csv
# 21 Brand: SAP, YouTube Link: https://www.youtube.com/user/SAP Going to Load:
# Subscribers: 117K subscribers
# 61
# ind : 0 What's New in SAP S/4HANA Cloud Public Edition 2408  – Product Release Highlights views : 3100 likes : 58, comments : 0
# ind : 1 Intelligent ERP &The AI Copilot Joule Update |  SAP S/4HANA Cloud Public Edition 2408 views : 1200 likes : 27, comments : 0
# ind : 2 SAP User Experience in SAP S/4HANA Cloud Public Edition 2408 views : 449 likes : 9, comments : 0
# ind : 3 Finance in SAP S/4HANA Cloud Public Edition 2408 views : 425 likes : 5, comments : 0
# ind : 4 Asset Management in SAP S/4HANA Cloud Public Edition 2408 views : 312 likes : 3, comments : 0
# Data saved to 2024-08-11 19-30-10/SAP_data.csv
# 22 Brand: Mercedes-Benz, YouTube Link: https://www.youtube.com/user/mercedesbenz Going to Load:
# Subscribers: 447K subscribers
# 31
# ind : 0 Panagiota Petridou unterwegs mit dem vollelektrischen Mercedes-Benz EQT: Part 3 - Der Großeinkauf views : 5200 likes : 79, comments : 10
# ind : 1 Die neue E-Klasse. views : 53000 likes : 233, comments : 23
# ind : 2 Das neue CLE Coupé: Shaped by Desire. views : 23000 likes : 241, comments : 16
# ind : 3 „Mein Mercedes“: Dennis Heyn trifft Anna und ihren CLA "Bloody Mary" views : 218000 likes : 400, comments : 0
# ind : 4 „Mein Mercedes“: Dennis Heyn stellt Matthias Malmedie seinen SL vor views : 467000 likes : 1700, comments : 0
# Data saved to 2024-08-11 19-30-10/Mercedes-Benz_data.csv
# 23 Brand: IBM, YouTube Link: https://www.youtube.com/user/IBM Going to Load:
# Subscribers: 336K subscribers
# 41
# ind : 0 IBM: Let’s create AI assistants that transform business with watsonx views : 7000 likes : 74, comments : 1
# ind : 1 IBM: Let’s create the right AI for your business with watsonx views : 10000 likes : 89, comments : 7
# ind : 2 IBM: Let’s create AI that begins with trust with watsonx.governance views : 3500000 likes : 69, comments : 11
# ind : 3 IBM: Let’s create a more modern foundation for business with watsonx Code Assistant views : 6200000 likes : 152, comments : 18
# ind : 4 IBM: Let’s create customer service in service of customers with watsonx Assistant views : 4200000 likes : 81, comments : 5
# Data saved to 2024-08-11 19-30-10/IBM_data.csv
# 24 Brand: Burger King, YouTube Link: https://www.youtube.com/user/burgerking Going to Load:
# Error finding subscribers: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//span[contains(@class, "yt-content-metadata-view-model-wiz__metadata-text") and contains(text(), "subscribers")]"}
#   (Session info: chrome=127.0.6533.89)
# Stacktrace:
# 	GetHandleVerifier [0x00007FF688A99632+30946]
# 	(No symbol) [0x00007FF688A4E3C9]
# 	(No symbol) [0x00007FF688946FDA]
# 	(No symbol) [0x00007FF68899822C]
# 	(No symbol) [0x00007FF68899850C]
# 	(No symbol) [0x00007FF6889DDCB7]
# 	(No symbol) [0x00007FF6889BCAAF]
# 	(No symbol) [0x00007FF6889DB041]
# 	(No symbol) [0x00007FF6889BC813]
# 	(No symbol) [0x00007FF68898A6E5]
# 	(No symbol) [0x00007FF68898B021]
# 	GetHandleVerifier [0x00007FF688BCF83D+1301229]
# 	GetHandleVerifier [0x00007FF688BDBDB7+1351783]
# 	GetHandleVerifier [0x00007FF688BD2A03+1313971]
# 	GetHandleVerifier [0x00007FF688ACDD06+245686]
# 	(No symbol) [0x00007FF688A5758F]
# 	(No symbol) [0x00007FF688A53804]
# 	(No symbol) [0x00007FF688A53992]
# 	(No symbol) [0x00007FF688A4A3EF]
# 	BaseThreadInitThunk [0x00007FFA045C257D+29]
# 	RtlUserThreadStart [0x00007FFA05F4AF28+40]
#
# 0
# Data saved to 2024-08-11 19-30-10/Burger King_data.csv
# 25 Brand: Netflix, YouTube Link: https://www.youtube.com/user/Netflix Going to Load:
# Error finding subscribers: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//span[contains(@class, "yt-content-metadata-view-model-wiz__metadata-text") and contains(text(), "subscribers")]"}
#   (Session info: chrome=127.0.6533.89)
# Stacktrace:
# 	GetHandleVerifier [0x00007FF688A99632+30946]
# 	(No symbol) [0x00007FF688A4E3C9]
# 	(No symbol) [0x00007FF688946FDA]
# 	(No symbol) [0x00007FF68899822C]
# 	(No symbol) [0x00007FF68899850C]
# 	(No symbol) [0x00007FF6889DDCB7]
# 	(No symbol) [0x00007FF6889BCAAF]
# 	(No symbol) [0x00007FF6889DB041]
# 	(No symbol) [0x00007FF6889BC813]
# 	(No symbol) [0x00007FF68898A6E5]
# 	(No symbol) [0x00007FF68898B021]
# 	GetHandleVerifier [0x00007FF688BCF83D+1301229]
# 	GetHandleVerifier [0x00007FF688BDBDB7+1351783]
# 	GetHandleVerifier [0x00007FF688BD2A03+1313971]
# 	GetHandleVerifier [0x00007FF688ACDD06+245686]
# 	(No symbol) [0x00007FF688A5758F]
# 	(No symbol) [0x00007FF688A53804]
# 	(No symbol) [0x00007FF688A53992]
# 	(No symbol) [0x00007FF688A4A3EF]
# 	BaseThreadInitThunk [0x00007FFA045C257D+29]
# 	RtlUserThreadStart [0x00007FFA05F4AF28+40]
#
# 0
# Data saved to 2024-08-11 19-30-10/Netflix_data.csv
# 26 Brand: BMW, YouTube Link: https://www.youtube.com/user/BMW Going to Load:
# Subscribers: 1.52M subscribers
# 66
# Could not find factoid element.
# ind : 0 The BMW Vision Neue Klasse X. views : 105000 likes : 0, comments : 287
# ind : 1 THE NEW MATERIALS - BMW Vision Neue Klasse X. views : 27000 likes : 749, comments : 37
# ind : 2 THE NEW PERSPECTIVE - BMW Vision Neue Klasse X. views : 14000 likes : 650, comments : 17
# ind : 3 THE NEW ELECTRIC - BMW Vision Neue Klasse X. views : 12000 likes : 725, comments : 15
# ind : 4 THE NEW FRIENDS - BMW Vision Neue Klasse X. views : 19000 likes : 763, comments : 35
# Data saved to 2024-08-11 19-30-10/BMW_data.csv
# 27 Brand: American Express, YouTube Link: https://www.youtube.com/user/AmericanExpress Going to Load:
# Subscribers: 200K subscribers
# 41
# ind : 0 Get to Know the Different Types of IRAs | American Express views : 1400 likes : 23, comments : 4
# Error finding views: list index out of range
# ind : 1 無限驚喜 從美國運通開始 | 夢幻禮遇  即刻享受 | American Express views : 1180784 likes : 69, comments : 0
# ind : 2 All By Myself | American Express views : 3600 likes : 56, comments : 0
# ind : 3 All By Myself | American Express views : 2800 likes : 48, comments : 0
# ind : 4 Float On | American Express views : 1100 likes : 11, comments : 0
# Data saved to 2024-08-11 19-30-10/American Express_data.csv
# 28 Brand: Honda, YouTube Link: https://www.youtube.com/user/Honda Going to Load:
# Subscribers: 622K subscribers
# 68
# ind : 0 Honda Prologue views : 208000 likes : 52, comments : 1
# ind : 1 Honda Civic views : 15000 likes : 329, comments : 0
# ind : 2 Honda CR-V views : 1800000 likes : 9900, comments : 685
# ind : 3 Honda Accord views : 61000 likes : 122, comments : 0
# ind : 4 Honda HR-V views : 39000 likes : 133, comments : 7
# Data saved to 2024-08-11 19-30-10/Honda_data.csv
# 29 Brand: L'Oréal, YouTube Link: https://www.youtube.com/user/lorealparisnyc Going to Load:
# Subscribers: 224K subscribers
# 52
# An error occurred: invalid literal for int() with base 10: 'N/A'

# %%
# df = pd.DataFrame([[2,1],[4,5]], columns=['Video Title', 'Video URL'])
# filename = f"2024-08-11 18-40-26/Apple_data.csv"
# df.to_csv(filename, index=False)
